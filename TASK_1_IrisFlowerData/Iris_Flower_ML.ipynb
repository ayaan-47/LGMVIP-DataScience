# %% [markdown]
# # Iris Flowers Classification Machine Learning Project
# # Author : Ayaan Lone
# ## Data Science Intern at LetsGrowMore

# %%
# Importing all the necessary libraries 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn import datasets

# %% [markdown]
# # We Have used Pandas library to read our data

# %%
# Using "Pandas" Library to read the data 
dset = pd.read_csv('iris_data.csv')

# %% [markdown]
# # Displaying The first 5 rows of our datasheet

# %%
# ".head" shows us the first 5 Rows of the datasheet
dset.head()
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Length.1        Class
# 0           5.1          3.5           1.4             0.2  Iris-setosa
# 1           4.9          3.0           1.4             0.2  Iris-setosa
# 2           4.7          3.2           1.3             0.2  Iris-setosa
# 3           4.6          3.1           1.5             0.2  Iris-setosa
# 4           5.0          3.6           1.4             0.2  Iris-setosa

# %% [markdown]
# # Displaying the Last 5 rows of our datasheet

# %%
# ".tail" Shows us the last five rows of the datasheet 
dset.tail()
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Length.1           Class
# 145           6.7          3.0           5.2             2.3  Iris-virginica
# 146           6.3          2.5           5.0             1.9  Iris-virginica
# 147           6.5          3.0           5.2             2.0  Iris-virginica
# 148           6.2          3.4           5.4             2.3  Iris-virginica
# 149           5.9          3.0           5.1             1.8  Iris-virginica

# %% [markdown]
# # For Counting the total values in a column

# %%
# To count Total values in a column using value_counts()
dset['Class'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Class, dtype: int64

# %% [markdown]
# # Getting the Mean, Count, Standard Deviation, Max, Min.....

# %%
# Use .describe() to Get detailed information Mean , Count , Standard Deviation , Maximum , Minimum , Quartile etc... 
dset.describe()
# Out:
#        Sepal Length  Sepal Width  Petal Length  Petal Length.1
# count    150.000000   150.000000    150.000000      150.000000
# mean       5.843333     3.054000      3.758667        1.198667
# std        0.828066     0.433594      1.764420        0.763161
# min        4.300000     2.000000      1.000000        0.100000
# 25%        5.100000     2.800000      1.600000        0.300000
# 50%        5.800000     3.000000      4.350000        1.300000
# 75%        6.400000     3.300000      5.100000        1.800000
# max        7.900000     4.400000      6.900000        2.500000

# %% [markdown]
# # Counting total Data in each Column

# %%
# use .count to Count total Data 
dset.count()
# Out:
# Sepal Length      150
# Sepal Width       150
# Petal Length      150
# Petal Length.1    150
# Class             150
# dtype: int64

# %% [markdown]
# # Checking the shape of the datasheet and other information

# %%
# To Check the shape of the data use .shape
dset.shape
# Out:
# (150, 5)

# %%
# To check for any null data present using .isnull().sum()
dset.isnull().sum()
# Out:
# Sepal Length      0
# Sepal Width       0
# Petal Length      0
# Petal Length.1    0
# Class             0
# dtype: int64

# %%
dset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sepal Length    150 non-null    float64
#  1   Sepal Width     150 non-null    float64
#  2   Petal Length    150 non-null    float64
#  3   Petal Length.1  150 non-null    float64
#  4   Class           150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # Data Visualization

# %%
# DATA_VISUALIZATION

dset = pd.read_csv('iris_data.csv')
sns.set_theme(style="dark", palette="dark")
sns.pairplot(dset, hue='Class', markers=["1","2","3"], palette=["r","g","b"] )
plt.show()

# %%
sns.set_theme(style="dark", palette="bright")
sns.boxplot(x="Class", y="Sepal Length",
            hue="Class", palette=["y","g","b"],
            data=dset)
sns.despine(offset=10, trim=True)

# %%
from sklearn.model_selection import train_test_split
X = dset.drop(['Class'], axis=1)
y = dset['Class']
from sklearn.preprocessing import StandardScaler
X = StandardScaler().fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
log_reg.score(X_train, y_train)
# Out:
# 0.9821428571428571

# %%
log_reg.score(X, y)
# Out:
# 0.96

# %%
log_reg.score(X_test, y_test)
# Out:
# 0.8947368421052632

# %%
#For Checking Accuracy of Model
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.svm import SVC
model = SVC(gamma='auto')
model.fit(X_train, y_train)
prediction = model.predict(X_test)
print(f'The Accuracy of the Model is  : " {accuracy_score(y_test, prediction)}"')
print(f'Here is the Report of the Model : \n {classification_report(y_test, prediction)}')
# Out:
# The Accuracy of the Model is  : " 0.8947368421052632"
# Here is the Report of the Model :
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       0.80      0.92      0.86        13
#  Iris-virginica       0.92      0.80      0.86        15
#
#        accuracy                           0.89        38
#       macro avg       0.91      0.91      0.90        38
#    weighted avg       0.90      0.89      0.89        38

# %% [markdown]
# # Hence the Accuracy of our model is 89 percent
